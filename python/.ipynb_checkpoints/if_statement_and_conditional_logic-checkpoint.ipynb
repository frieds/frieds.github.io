# %% [markdown]
# Title: If statement and conditional logic
# Slug: if_statement_conditional_logic
# Summary: Perform conditional evaluation
# Date: 2018-02-20 18:00
# Category: Python
# Tags: math
# Authors: Dan Friedman
